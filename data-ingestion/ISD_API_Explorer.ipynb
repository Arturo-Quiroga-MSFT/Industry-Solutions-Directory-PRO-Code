# %% [markdown]
# ## Setup
#
# Import required libraries

# %%
import requests
import json
import pandas as pd
from collections import Counter
from IPython.display import display, HTML, Markdown
import time

# API Configuration
API_BASE = "https://mssoldir-app-prd.azurewebsites.net/api/Industry"

print("✅ Libraries imported successfully")
print(f"📡 API Base URL: {API_BASE}")
# Out:
# ✅ Libraries imported successfully
# 📡 API Base URL: https://mssoldir-app-prd.azurewebsites.net/api/Industry

# %% [markdown]
# ## 1. Industry Menu API
#
# The **getMenu** endpoint returns the complete industry hierarchy including industries, themes, and solution areas.

# %%
# Fetch the industry menu
menu_url = f"{API_BASE}/getMenu"
print(f"📥 Fetching industry menu from: {menu_url}")

response = requests.get(menu_url, timeout=30)
response.raise_for_status()
menu_data = response.json()

print(f"✅ Successfully fetched menu data")
print(f"📊 Number of industries: {len(menu_data)}")
# Out:
# 📥 Fetching industry menu from: https://mssoldir-app-prd.azurewebsites.net/api/Industry/getMenu
# ✅ Successfully fetched menu data
# 📊 Number of industries: 10

# %% [markdown]
# ### Display Industry Overview

# %%
# Create a DataFrame of industries and their themes
industry_overview = []

for industry in menu_data:
    industry_name = industry.get("industryName", "Unknown")
    sub_industries = industry.get("subIndustries", [])
    
    for sub in sub_industries:
        solution_areas = sub.get("solutionAreas") or []
        industry_overview.append({
            "Industry": industry_name,
            "Theme": sub.get("subIndustryName", "Unknown"),
            "Theme Slug": sub.get("industryThemeSlug", "N/A"),
            "Solution Areas": len(solution_areas)
        })

df_industries = pd.DataFrame(industry_overview)
print(f"\n📋 Total Industries: {df_industries['Industry'].nunique()}")
print(f"📋 Total Themes: {len(df_industries)}")
print(f"\n🔍 First 40 themes:")
display(df_industries.head(40))
# Out:
# 📋 Total Industries: 10
# 📋 Total Themes: 40
#
# 🔍 First 40 themes:
#                       Industry  \
# 0      Defense Industrial Base
# 1                    Education
# 2                    Education
# 3                    Education
# 4                    Education
# 5           Energy & Resources
# 6           Energy & Resources
# 7           Energy & Resources
# 8           Energy & Resources
# 9           Financial Services
# 10          Financial Services
# 11          Financial Services
# 12          Financial Services
# 13          Financial Services
# 14  Healthcare & Life Sciences
# 15  Healthcare & Life Sciences
# 16  Healthcare & Life Sciences
# 17  Healthcare & Life Sciences
# 18  Healthcare & Life Sciences
# 19    Manufacturing & Mobility
# 20    Manufacturing & Mobility
# 21    Manufacturing & Mobility
# 22    Manufacturing & Mobility
# 23    Manufacturing & Mobility
# 24       Media & Entertainment
# 25       Media & Entertainment
# 26       Media & Entertainment
# 27       Media & Entertainment
# 28     Retail & Consumer Goods
# 29     Retail & Consumer Goods
# 30     Retail & Consumer Goods
# 31     Retail & Consumer Goods
# 32    State & Local Government
# 33    State & Local Government
# 34    State & Local Government
# 35    State & Local Government
# 36    State & Local Government
# 37          Telecommunications
# 38          Telecommunications
# 39          Telecommunications
#
#                                                 Theme  \
# 0   Sharpen Your Competitive Edge with AI-Infused ...
# 1                            Institutional Innovation
# 2                              Simplify and Secure IT
# 3                                     Student Success
# 4                                    testing industry
# 5                       Advance Your Net-Zero Journey
# 6                Empower an AI-First Energy Workforce
# 7             Grow Sustainable, AI-Powered Businesses
# 8    Operate for a Secure and Efficient Energy Future
# 9                     Empowering Employees and Agents
# 10                       Managing Risk and Compliance
# 11  Modernize Core Systems, Payments and Data Plat...
# 12              Modernizing Core Systems and Payments
# 13                  Transform the Customer Experience
# 14                                          Data & AI
# 15                          Electronic Health Records
# 16                   Empower the Healthcare Workforce
# 17             Enhance Patient and Member Experiences
# 18    Unlock Value from Clinical and Operational Data
# 19                     Connected Customer Experiences
# 20                   Innovate in Engineering with AI
# 21                              Intelligent Factories
# 22               Resilient Manufacturing Supply Chain
# 23                            Resilient Supply Chains
# 24                           Empower Content Creators
# 25                                Optimize Operations
# 26                   Personalize Customer Experiences
# 27                                Unlock Monetization
# 28                                     Consumer Goods
# 29  Design Next-Gen Products and Optimize Revenue ...
# 30                  Optimize Merchandising Operations
# 31  Transform the Shopper Experience and Build Bra...
# 32        Deliver Personalized Government Experiences
# 33                   Empower the Government Workforce
# 34                   Enable AI-Driven Decision Making
# 35                   Optimize Critical Infrastructure
# 36         Secure Government Data & Protect Resources
# 37                           Grow Beyond Connectivity
# 38                  Optimize with Autonomous Networks
# 39            Secure and Automate Business Operations
#
#                                            Theme Slug  Solution Areas
# 0   sharpen-your-competitive-edge-with-cloud-based...               3
# 1   improve-operational-efficiencies-for-modernize...               3
# 2   simplified-and-secure-it-to-deliver-safe-and-s...               2
# 3   microsoft-and-its-top-education-partners-help1...               3
# 4                                                None               0
# 5   reach-net-zero-commitments-through-emissions-r...               2
# 6   automate-workflows-and-improve-ai-enabled-recr...               2
# 7   unlock-data-insights-that-accelerate-climate-i...               2
# 8   energy-companies-transforming-operations-to-po...               2
# 9   microsoft-is-empowering-employees-in-the-finan...               3
# 10  navigating-a-changing-financial-services-risk-...               3
# 11          modernizing-core-systems-and-payments-819               3
# 12                                               None               0
# 13              transform-the-customer-experience-959               3
# 14                                               None               0
# 15                       electronic-health-records-13               3
# 16                   empower-the-healthcare-workforce               3
# 17         enhance-patient-and-member-experiences-118               3
# 18  unlock-value-from-clinical-and-operational-dat...               3
# 19  10-10-10-increase10-customer-satisfaction-and-...               1
# 20  the-next-evolution-of-manufacturing-the-indust...               3
# 21                   enable-intelligent-factories-925               2
# 22                                               None               0
# 23     resilient-manufacturing-supply-chain160160-715               1
# 24                       empower-content-creators-336               3
# 25                            optimize-operations-653               3
# 26                   personalize-customer-experiences               3
# 27                            unlock-monetization-876               3
# 28                                               None               0
# 29  design-next-gen-products-and-optimize-revenue-...               3
# 30                maximize-the-value-of-your-data-719               3
# 31  develop-next-gen-products-and-growth-via-ai-dr...               3
# 32    deliver-personalized-government-experiences-521               3
# 33               empower-the-government-workforce-777               3
# 34                   enable-ai-driven-decision-making               3
# 35  optimize-critical-infrastructure-planning-desi...               2
# 36       secure-government-data-amp-protect-resources               3
# 37                        grow-beyond-connectivity-41               3
# 38              optimize-with-autonomous-networks-736               3
# 39         secure-and-automate-business-operations-23               3

# %% [markdown]
# ### Industry Summary Statistics

# %%
# Count themes per industry
themes_per_industry = df_industries.groupby('Industry').size().sort_values(ascending=False)

print("📊 Themes per Industry:")
for industry, count in themes_per_industry.items():
    print(f"  • {industry}: {count} themes")
# Out:
# 📊 Themes per Industry:
#   • Financial Services: 5 themes
#   • Healthcare & Life Sciences: 5 themes
#   • Manufacturing & Mobility: 5 themes
#   • State & Local Government: 5 themes
#   • Education: 4 themes
#   • Energy & Resources: 4 themes
#   • Media & Entertainment: 4 themes
#   • Retail & Consumer Goods: 4 themes
#   • Telecommunications: 3 themes
#   • Defense Industrial Base: 1 themes

# %% [markdown]
# ### Inspect a Sample Industry Structure

# %%
# Display the first industry in detail (formatted JSON)
sample_industry = menu_data[0]

print("📄 Sample Industry Structure (Education):")
print("\nIndustry Level:")
print(json.dumps({
    "industryId": sample_industry.get("industryId"),
    "industryName": sample_industry.get("industryName"),
    "industrySlug": sample_industry.get("industrySlug"),
    "hasMultipleTheme": sample_industry.get("hasMultipleThme"),
    "hasSubMenu": sample_industry.get("hasSubMenu")
}, indent=2))

print("\nFirst Theme/Sub-Industry:")
if sample_industry.get("subIndustries"):
    first_theme = sample_industry["subIndustries"][0]
    print(json.dumps({
        "subIndustryName": first_theme.get("subIndustryName"),
        "subIndustrySlug": first_theme.get("subIndustrySlug"),
        "industryThemeSlug": first_theme.get("industryThemeSlug"),
        "solutionAreas": [area.get("solutionAreaName") for area in first_theme.get("solutionAreas", [])]
    }, indent=2))
# Out:
# 📄 Sample Industry Structure (Education):
#
# Industry Level:
# {
#   "industryId": "1a3b63eb-c5ae-4006-96fd-30401132676f",
#   "industryName": "Defense Industrial Base",
#   "industrySlug": "defense-industrial-base",
#   "hasMultipleTheme": false,
#   "hasSubMenu": true
# }
#
# First Theme/Sub-Industry:
# {
#   "subIndustryName": "Sharpen Your Competitive Edge with AI-Infused Cloud Tech",
#   "subIndustrySlug": "sharpen-your-competitive-edge-with-ai-infused-cloud-tech-483",
#   "industryThemeSlug": "sharpen-your-competitive-edge-with-cloud-based-digital-first-offerings-infused-with-data-and-ai",
#   "solutionAreas": [
#     "AI Business Solutions",
#     "Cloud and AI Platforms",
#     "Security"
#   ]
# }

# %% [markdown]
# ## 2. Theme Details API
#
# The **GetThemeDetalsByViewId** endpoint returns all solutions for a specific theme.

# %%
# Pick a theme to explore - find one that has solutions
sample_theme_slug = None
sample_theme_name = None
sample_industry_name = None

print("🔍 Looking for a theme with solutions...")

for industry in menu_data:
    for sub in industry.get("subIndustries", []):
        slug = sub.get("industryThemeSlug")
        if slug:
            # Test this theme to see if it has solutions
            try:
                test_response = requests.get(
                    f"{API_BASE}/GetThemeDetalsByViewId",
                    params={"slug": slug},
                    timeout=30
                )
                if test_response.status_code == 200:
                    test_data = test_response.json()
                    
                    # Check if this theme has any actual partner solutions
                    has_solutions = False
                    
                    # Check solution areas for partner solutions
                    for area in test_data.get("themeSolutionAreas", []):
                        if area.get("partnerSolutions") and len(area["partnerSolutions"]) > 0:
                            has_solutions = True
                            break
                    
                    # Also check spotlight solutions
                    if not has_solutions and test_data.get("spotLightPartnerSolutions"):
                        has_solutions = len(test_data["spotLightPartnerSolutions"]) > 0
                    
                    if has_solutions:
                        sample_theme_slug = slug
                        sample_theme_name = sub.get("subIndustryName", "Unknown")
                        sample_industry_name = industry.get("industryName", "Unknown")
                        theme_data = test_data  # Use the data we already fetched
                        break
            except Exception as e:
                continue
        
    if sample_theme_slug:
        break

if not sample_theme_slug:
    raise Exception("Could not find a theme with solutions")

print(f"✅ Found theme with solutions: {sample_industry_name} > {sample_theme_name}")
print(f"   Slug: {sample_theme_slug}")
print(f"\n📊 Theme Overview:")
print(f"  • Theme Title: {theme_data.get('industryThemeTitle', 'N/A')}")
print(f"  • Solution Areas: {len(theme_data.get('themeSolutionAreas', []))}")
print(f"  • Spotlight Solutions: {len(theme_data.get('spotLightPartnerSolutions', []))}")
# Out:
# 🔍 Looking for a theme with solutions...
# ✅ Found theme with solutions: Education > Institutional Innovation
#    Slug: improve-operational-efficiencies-for-modernized-school-experiences-850
#
# 📊 Theme Overview:
#   • Theme Title: N/A
#   • Solution Areas: 3
#   • Spotlight Solutions: 3

# %% [markdown]
# ### Extract Solutions from Theme

# %%
# Extract all solutions from this theme
solutions = []

# Regular solutions from solution areas
for area in theme_data.get("themeSolutionAreas", []):
    area_name = area.get("solutionAreaName", "Unknown")
    
    for sol in area.get("partnerSolutions", []):
        title = sol.get("solutionName", "")
        
        # Extract partner from title (format: "Solution by Partner")
        partner = title.split(" by ")[-1] if " by " in title else "Unknown"
        
        solutions.append({
            "Solution ID": sol.get("partnerSolutionId"),
            "Title": title,
            "Partner": partner,
            "Solution Area": area_name,
            "Type": "Regular",
            "Description Length": len(sol.get("solutionDescription", "")),
            "URL": f"https://solutions.microsoftindustryinsights.com/solutiondetails/{sol.get('partnerSolutionSlug', '')}"
        })

# Spotlight solutions
for sol in theme_data.get("spotLightPartnerSolutions", []):
    title = sol.get("solutionName", "")
    partner = title.split(" by ")[-1] if " by " in title else "Unknown"
    
    solutions.append({
        "Solution ID": sol.get("partnerSolutionId"),
        "Title": title,
        "Partner": partner,
        "Solution Area": "Spotlight",
        "Type": "Spotlight",
        "Description Length": len(sol.get("solutionDescription", "")),
        "URL": f"https://solutions.microsoftindustryinsights.com/solutiondetails/{sol.get('partnerSolutionSlug', '')}"
    })

df_solutions = pd.DataFrame(solutions)
print(f"\n✅ Extracted {len(df_solutions)} solutions from this theme")

if len(df_solutions) > 0:
    print(f"\n🔍 Sample Solutions:")
    display(df_solutions[['Title', 'Partner', 'Solution Area', 'Type']].head(10))
else:
    print("\n⚠️  No solutions found in this theme")
# Out:
# ✅ Extracted 54 solutions from this theme
#
# 🔍 Sample Solutions:
#                                                Title            Partner  \
# 0  greymatter Student Lifecycle CRM by Frequency ...  Frequency Foundry
# 1                                                CDW            Unknown
# 2               Blackbaud Enterprise Fundraising CRM            Unknown
# 3                         Higher Education Blueprint            Unknown
# 4       PwC Digital Relationship Management Solution            Unknown
# 5                                NICE-20240419022414            Unknown
# 6                      Nerdio Manager for Enterprise            Unknown
# 7                PwC Total Professional Effort (TPE)            Unknown
# 8                         Terawe Corporation ManageX            Unknown
# 9                                      AvePoint Inc             Unknown
#
#            Solution Area     Type
# 0  AI Business Solutions  Regular
# 1  AI Business Solutions  Regular
# 2  AI Business Solutions  Regular
# 3  AI Business Solutions  Regular
# 4  AI Business Solutions  Regular
# 5  AI Business Solutions  Regular
# 6  AI Business Solutions  Regular
# 7  AI Business Solutions  Regular
# 8  AI Business Solutions  Regular
# 9  AI Business Solutions  Regular

# %% [markdown]
# ### Inspect a Sample Solution

# %%
# Get the first solution for detailed inspection
if theme_data.get("themeSolutionAreas") and len(theme_data["themeSolutionAreas"]) > 0:
    first_area = theme_data["themeSolutionAreas"][0]
    if first_area.get("partnerSolutions") and len(first_area["partnerSolutions"]) > 0:
        first_solution = first_area["partnerSolutions"][0]

        print("📄 Sample Solution Structure:")
        print("\nKey Fields:")
        print(json.dumps({
            "partnerSolutionId": first_solution.get("partnerSolutionId"),
            "solutionName": first_solution.get("solutionName"),
            "partnerSolutionSlug": first_solution.get("partnerSolutionSlug"),
            "orgName": first_solution.get("orgName"),  # Often null
            "publisherName": first_solution.get("publisherName"),  # Often null
            "descriptionLength": len(first_solution.get("solutionDescription", "")),
        }, indent=2))

        print("\n📝 Solution Description (first 500 chars):")
        description = first_solution.get("solutionDescription", "")
        print(description[:500] + "..." if len(description) > 500 else description)
    else:
        print("⚠️  No partner solutions found in the first solution area")
else:
    print("⚠️  No solution areas found in this theme")
# Out:
# 📄 Sample Solution Structure:
#
# Key Fields:
# {
#   "partnerSolutionId": "bd8cdf5a-42b2-4396-920f-514c9e040430",
#   "solutionName": "greymatter Student Lifecycle CRM by Frequency Foundry",
#   "partnerSolutionSlug": "greymatter-student-lifecycle-crm-by-frequency-foundry",
#   "orgName": "greymatter Student Lifecycle CRM by Frequency Foundry",
#   "publisherName": null,
#   "descriptionLength": 3978
# }
#
# 📝 Solution Description (first 500 chars):
# <p>Frequency Foundry&rsquo;s greymatter Student Lifecycle CRM is a Customer Relationship Management solution built from the ground up for higher education that includes robust and flexible, recruiting and admissions features, advising, retention, and early alert functionality, as well as coverage for nearly every aspect of the student lifecycle that has an impact on the student experience. The Foundry understands that every higher education institution is unique in its student experience challen...

# %% [markdown]
# ## 3. Complete Data Extraction (All Solutions)
#
# Now let's fetch solutions from multiple themes to get a broader view.

# %%
# Fetch solutions from first 3 themes (to keep execution time reasonable)
all_solutions = []
themes_to_fetch = 3

print(f"📥 Fetching solutions from {themes_to_fetch} themes...\n")

count = 0
for industry in menu_data:
    industry_name = industry.get("industryName")
    
    for theme in industry.get("subIndustries", []):
        if count >= themes_to_fetch:
            break
            
        theme_name = theme.get("subIndustryName")
        theme_slug = theme.get("industryThemeSlug")
        
        if not theme_slug:
            continue
        
        print(f"  Fetching: {industry_name} > {theme_name}")
        
        try:
            response = requests.get(
                f"{API_BASE}/GetThemeDetalsByViewId",
                params={"slug": theme_slug},
                timeout=30
            )
            response.raise_for_status()
            theme_data = response.json()
            
            # Extract solutions
            for area in theme_data.get("themeSolutionAreas", []):
                for sol in area.get("partnerSolutions", []):
                    title = sol.get("solutionName", "")
                    partner = title.split(" by ")[-1] if " by " in title else "Unknown"
                    
                    all_solutions.append({
                        "Industry": industry_name,
                        "Theme": theme_name,
                        "Title": title,
                        "Partner": partner,
                        "Description Length": len(sol.get("solutionDescription", ""))
                    })
            
            count += 1
            time.sleep(0.5)  # Be polite to the API
            
        except Exception as e:
            print(f"    ⚠️  Error: {e}")
            continue
    
    if count >= themes_to_fetch:
        break

df_all = pd.DataFrame(all_solutions)
print(f"\n✅ Total solutions fetched: {len(df_all)}")
print(f"📊 Unique partners: {df_all['Partner'].nunique()}")
# Out:
# 📥 Fetching solutions from 3 themes...
#
#   Fetching: Defense Industrial Base > Sharpen Your Competitive Edge with AI-Infused Cloud Tech
#   Fetching: Education > Institutional Innovation
#   Fetching: Education > Simplify and Secure IT
#
# ✅ Total solutions fetched: 62
# 📊 Unique partners: 2

# %% [markdown]
# ## 4. Partner Analysis
#
# Analyze the distribution of solutions across partners.

# %%
# Count solutions per partner
partner_counts = df_all['Partner'].value_counts().head(10)

print("🏆 Top 10 Partners by Solution Count (from sample):")
for i, (partner, count) in enumerate(partner_counts.items(), 1):
    print(f"  {i}. {partner}: {count} solutions")

# Create a visualization-ready DataFrame
df_partner_summary = pd.DataFrame({
    'Partner': partner_counts.index,
    'Solution Count': partner_counts.values
})

display(df_partner_summary)
# Out:
# 🏆 Top 10 Partners by Solution Count (from sample):
#   1. Unknown: 60 solutions
#   2. Frequency Foundry: 2 solutions
#              Partner  Solution Count
# 0            Unknown              60
# 1  Frequency Foundry               2

# %% [markdown]
# ## 5. Industry Distribution

# %%
# Solutions per industry (from sample)
industry_counts = df_all['Industry'].value_counts()

print("📊 Solutions per Industry (from sample):")
for industry, count in industry_counts.items():
    print(f"  • {industry}: {count} solutions")
# Out:
# 📊 Solutions per Industry (from sample):
#   • Education: 62 solutions

# %% [markdown]
# ## 6. Content Analysis

# %%
# Analyze description lengths
print("📝 Description Length Statistics:")
print(f"  • Average: {df_all['Description Length'].mean():.0f} characters")
print(f"  • Median: {df_all['Description Length'].median():.0f} characters")
print(f"  • Min: {df_all['Description Length'].min()} characters")
print(f"  • Max: {df_all['Description Length'].max()} characters")

# Distribution
print("\n📊 Description Length Distribution:")
bins = [0, 1000, 2000, 3000, 5000, 10000]
labels = ['<1K', '1K-2K', '2K-3K', '3K-5K', '>5K']
df_all['Length Category'] = pd.cut(df_all['Description Length'], bins=bins, labels=labels)

for category in labels:
    count = (df_all['Length Category'] == category).sum()
    print(f"  • {category}: {count} solutions")
# Out:
# 📝 Description Length Statistics:
#   • Average: 1723 characters
#   • Median: 1099 characters
#   • Min: 324 characters
#   • Max: 5655 characters
#
# 📊 Description Length Distribution:
#   • <1K: 29 solutions
#   • 1K-2K: 17 solutions
#   • 2K-3K: 4 solutions
#   • 3K-5K: 9 solutions
#   • >5K: 3 solutions

# %% [markdown]
# ## 7. Sample Solution Details
#
# Display a few complete solution records.

# %%
print("📋 Sample Solution Records:\n")

for i, row in df_all.head(5).iterrows():
    print(f"{'='*70}")
    print(f"Solution #{i+1}")
    print(f"{'='*70}")
    print(f"Industry: {row['Industry']}")
    print(f"Theme: {row['Theme']}")
    print(f"Title: {row['Title']}")
    print(f"Partner: {row['Partner']}")
    print(f"Description Length: {row['Description Length']} chars")
    print()
# Out:
# 📋 Sample Solution Records:
#
# ======================================================================
# Solution #1
# ======================================================================
# Industry: Education
# Theme: Institutional Innovation
# Title: greymatter Student Lifecycle CRM by Frequency Foundry
# Partner: Frequency Foundry
# Description Length: 3978 chars
#
# ======================================================================
# Solution #2
# ======================================================================
# Industry: Education
# Theme: Institutional Innovation
# Title: CDW
# Partner: Unknown
# Description Length: 519 chars
#
# ======================================================================
# Solution #3
# ======================================================================
# Industry: Education
# Theme: Institutional Innovation
# Title: Blackbaud Enterprise Fundraising CRM
# Partner: Unknown
# Description Length: 561 chars
#
# ======================================================================
# Solution #4
# ======================================================================
# Industry: Education
# Theme: Institutional Innovation
# Title: Higher Education Blueprint
# Partner: Unknown
# Description Length: 1995 chars
#
# ======================================================================
# Solution #5
# ======================================================================
# Industry: Education
# Theme: Institutional Innovation
# Title: PwC Digital Relationship Management Solution
# Partner: Unknown
# Description Length: 1111 chars

# %% [markdown]
# ## 8. Data Export
#
# Export the collected data to CSV for further analysis.

# %%
# Export to CSV
output_file = "isd_sample_solutions.csv"
df_all.to_csv(output_file, index=False)

print(f"💾 Exported {len(df_all)} solutions to: {output_file}")
print(f"\n📊 Summary:")
print(f"  • Total Solutions: {len(df_all)}")
print(f"  • Unique Industries: {df_all['Industry'].nunique()}")
print(f"  • Unique Themes: {df_all['Theme'].nunique()}")
print(f"  • Unique Partners: {df_all['Partner'].nunique()}")
# Out:
# 💾 Exported 62 solutions to: isd_sample_solutions.csv
#
# 📊 Summary:
#   • Total Solutions: 62
#   • Unique Industries: 1
#   • Unique Themes: 2
#   • Unique Partners: 2

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
#
# 1. ✅ **Industry Menu API** - Retrieved complete industry hierarchy
# 2. ✅ **Theme Details API** - Fetched solutions for specific themes
# 3. ✅ **Data Parsing** - Extracted and structured solution information
# 4. ✅ **Partner Extraction** - Parsed partner names from solution titles
# 5. ✅ **Analysis** - Analyzed partner and industry distributions
# 6. ✅ **Content Inspection** - Examined description characteristics
#
# ### Key Findings
#
# - The ISD API uses a **two-phase approach**: Menu → Theme Details
# - Partner names are typically embedded in solution titles ("Solution by Partner")
# - Solution descriptions are HTML formatted and vary in length (500-5000+ chars)
# - Each solution has a unique ID and URL slug for direct access
#
# ### Next Steps
#
# - Run `integrated-vectorization/` scripts to index all solutions
# - Use `update-monitor/` scripts to detect changes
# - Query indexed data via the FastAPI backend
#
# ---
#
# **Documentation:** See [ISD_WEBSITE_STRUCTURE.md](ISD_WEBSITE_STRUCTURE.md) for detailed API documentation.
